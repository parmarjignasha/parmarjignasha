# %% [markdown]
# <a href="https://colab.research.google.com/github/parmarjignasha/parmarjignasha/blob/main/covid_19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/content/drive/MyDrive/worldometer_data.csv")
data.head()
# Out:
#   Country/Region      Continent    Population  TotalCases  NewCases  \
# 0            USA  North America  3.311981e+08     5032179       NaN
# 1         Brazil  South America  2.127107e+08     2917562       NaN
# 2          India           Asia  1.381345e+09     2025409       NaN
# 3         Russia         Europe  1.459409e+08      871894       NaN
# 4   South Africa         Africa  5.938157e+07      538184       NaN
#
#    TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# 0     162804.0        NaN       2576668.0           NaN    2292707.0
# 1      98644.0        NaN       2047660.0           NaN     771258.0
# 2      41638.0        NaN       1377384.0           NaN     606387.0
# 3      14606.0        NaN        676357.0           NaN     180931.0
# 4       9604.0        NaN        387316.0           NaN     141264.0
#
#    Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# 0           18296.0           15194.0          492.0  63139605.0
# ...

# %%
data.columns
# Out:
# Index(['Country/Region', 'Continent', 'Population', 'TotalCases', 'NewCases',
#        'TotalDeaths', 'NewDeaths', 'TotalRecovered', 'NewRecovered',
#        'ActiveCases', 'Serious,Critical', 'Tot Cases/1M pop', 'Deaths/1M pop',
#        'TotalTests', 'Tests/1M pop', 'WHO Region'],
#       dtype='object')

# %%
data.tail()
# Out:
#             Country/Region      Continent  Population  TotalCases  NewCases  \
# 204             Montserrat  North America      4992.0          13       NaN
# 205  Caribbean Netherlands  North America     26247.0          13       NaN
# 206       Falkland Islands  South America      3489.0          13       NaN
# 207           Vatican City         Europe       801.0          12       NaN
# 208         Western Sahara         Africa    598682.0          10       NaN
#
#      TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# 204          1.0        NaN            10.0           NaN          2.0
# 205          NaN        NaN             7.0           NaN          6.0
# 206          NaN        NaN            13.0           NaN          0.0
# 207          NaN        NaN            12.0           NaN          0.0
# 208          1.0        NaN             8.0           NaN          1.0
#
#      Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# ...

# %%
data.describe()
# Out:
#          Population    TotalCases     NewCases    TotalDeaths   NewDeaths  \
# count  2.080000e+02  2.090000e+02     4.000000     188.000000    3.000000
# mean   3.041549e+07  9.171850e+04  1980.500000    3792.590426  300.000000
# std    1.047661e+08  4.325867e+05  3129.611424   15487.184877  451.199512
# min    8.010000e+02  1.000000e+01    20.000000       1.000000    1.000000
# 25%    9.663140e+05  7.120000e+02    27.500000      22.000000   40.500000
# 50%    7.041972e+06  4.491000e+03   656.000000     113.000000   80.000000
# 75%    2.575614e+07  3.689600e+04  2609.000000     786.000000  449.500000
# max    1.381345e+09  5.032179e+06  6590.000000  162804.000000  819.000000
#
#        TotalRecovered  NewRecovered   ActiveCases  Serious,Critical  \
# count    2.050000e+02      3.000000  2.050000e+02        122.000000
# mean     5.887898e+04   1706.000000  2.766433e+04        534.393443
# std      2.566984e+05   2154.779803  1.746327e+05       2047.518613
# ...

# %%
data.isnull().sum()
# Out:
# Date                      0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# No. of countries          0
# dtype: int64

# %%
data.notnull().sum()
# Out:
# Date                      188
# Confirmed                 188
# Deaths                    188
# Recovered                 188
# Active                    188
# New cases                 188
# New deaths                188
# New recovered             188
# Deaths / 100 Cases        188
# Recovered / 100 Cases     188
# Deaths / 100 Recovered    188
# No. of countries          188
# dtype: int64

# %%
data.columns
# Out:
# Index(['Country/Region', 'Continent', 'Population', 'TotalCases', 'NewCases',
#        'TotalDeaths', 'NewDeaths', 'TotalRecovered', 'NewRecovered',
#        'ActiveCases', 'Serious,Critical', 'Tot Cases/1M pop', 'Deaths/1M pop',
#        'TotalTests', 'Tests/1M pop', 'WHO Region'],
#       dtype='object')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/content/drive/MyDrive/day_wise.csv")
data.head()
# Out:
#          Date  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0  2020-01-22        555      17         28     510          0           0
# 1  2020-01-23        654      18         30     606         99           1
# 2  2020-01-24        941      26         36     879        287           8
# 3  2020-01-25       1434      42         39    1353        493          16
# 4  2020-01-26       2118      56         52    2010        684          14
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0              0                3.06                   5.05
# 1              2                2.75                   4.59
# 2              6                2.76                   3.83
# 3              3                2.93                   2.72
# 4             13                2.64                   2.46
#
#    Deaths / 100 Recovered  No. of countries
# 0                   60.71                 6
# 1                   60.00                 8
# ...

# %%
data.columns
# Out:
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', 'Date', 'Confirmed',
#        'Deaths', 'Recovered', 'Active', 'WHO Region'],
#       dtype='object')

# %%
data.tail()
# Out:
#       Province/State         Country/Region        Lat       Long        Date  \
# 49063            NaN  Sao Tome and Principe   0.186400   6.613100  2020-07-27
# 49064            NaN                  Yemen  15.552727  48.516388  2020-07-27
# 49065            NaN                Comoros -11.645500  43.333300  2020-07-27
# 49066            NaN             Tajikistan  38.861000  71.276100  2020-07-27
# 49067            NaN                Lesotho -29.610000  28.233600  2020-07-27
#
#        Confirmed  Deaths  Recovered  Active             WHO Region
# 49063        865      14        734     117                 Africa
# 49064       1691     483        833     375  Eastern Mediterranean
# 49065        354       7        328      19                 Africa
# 49066       7235      60       6028    1147                 Europe
# 49067        505      12        128     365                 Africa

# %%
data.describe
# Out:
# <bound method NDFrame.describe of       Province/State         Country/Region        Lat       Long        Date  \
# 0                NaN            Afghanistan  33.939110  67.709953  2020-01-22
# 1                NaN                Albania  41.153300  20.168300  2020-01-22
# 2                NaN                Algeria  28.033900   1.659600  2020-01-22
# 3                NaN                Andorra  42.506300   1.521800  2020-01-22
# 4                NaN                 Angola -11.202700  17.873900  2020-01-22
# ...              ...                    ...        ...        ...         ...
# 49063            NaN  Sao Tome and Principe   0.186400   6.613100  2020-07-27
# 49064            NaN                  Yemen  15.552727  48.516388  2020-07-27
# 49065            NaN                Comoros -11.645500  43.333300  2020-07-27
# 49066            NaN             Tajikistan  38.861000  71.276100  2020-07-27
# 49067            NaN                Lesotho -29.610000  28.233600  2020-07-27
#
# ...

# %%
data.isnull().sum()
# Out:
# Province/State    34404
# Country/Region        0
# Lat                   0
# Long                  0
# Date                  0
# Confirmed             0
# Deaths                0
# Recovered             0
# Active                0
# WHO Region            0
# dtype: int64

# %%
import seaborn as sns
import pandas as pd

# %% [markdown]
# ***Relating the Variables with scatterplots***

# %%
sns.relplot(x='Confirmed',y='Recovered',data=data)

# %%
sns.relplot(x='Deaths',y='Recovered',hue='Active',data=data)

# %%
sns.pairplot(data)

# %%
data.columns
# Out:
# Index(['Date', 'Confirmed', 'Deaths', 'Recovered', 'Active', 'New cases',
#        'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered', 'No. of countries'],
#       dtype='object')

# %%
sns.relplot(x='Confirmed',y='Active',kind='line',data=data)

# %%
data.columns
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase',
#        'WHO Region'],
#       dtype='object')

# %%
sns.catplot(x='Active',y='Recovered',data=data)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/content/drive/MyDrive/country_wise_latest.csv")
data.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
data.describe
# Out:
# <bound method NDFrame.describe of          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
# ...

# %%
data.columns
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase',
#        'WHO Region'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Country/Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# Confirmed last week       0
# 1 week change             0
# 1 week % increase         0
# WHO Region                0
# dtype: int64

# %%
data.notnull().sum()
# Out:
# Country/Region            187
# Confirmed                 187
# Deaths                    187
# Recovered                 187
# Active                    187
# New cases                 187
# New deaths                187
# New recovered             187
# Deaths / 100 Cases        187
# Recovered / 100 Cases     187
# Deaths / 100 Recovered    187
# Confirmed last week       187
# 1 week change             187
# 1 week % increase         187
# WHO Region                187
# dtype: int64

# %%
import seaborn as sns
import pandas as pd

# %% [markdown]
# ***Relating the Variables with scatterplots***

# %%
sns.relplot(x='New cases',y='New recovered',data=data)

# %%
sns.relplot(x='New deaths',y='New recovered',hue='Active',data=data)

# %%
sns.pairplot(data)

# %%
data.columns
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase',
#        'WHO Region'],
#       dtype='object')

# %%
sns.relplot(x='Deaths',y='Active',kind='line',data=data)

# %%
data.columns
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase',
#        'WHO Region'],
#       dtype='object')

# %%
sns.catplot(x='New cases',y='Recovered',data=data)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/content/drive/MyDrive/usa_county_wise.csv")
data.head()
# Out:
#         UID iso2 iso3  code3     FIPS    Admin2            Province_State  \
# 0        16   AS  ASM     16     60.0       NaN            American Samoa
# 1       316   GU  GUM    316     66.0       NaN                      Guam
# 2       580   MP  MNP    580     69.0       NaN  Northern Mariana Islands
# 3  63072001   PR  PRI    630  72001.0  Adjuntas               Puerto Rico
# 4  63072003   PR  PRI    630  72003.0    Aguada               Puerto Rico
#
#   Country_Region        Lat       Long_                  Combined_Key  \
# 0             US -14.271000 -170.132000            American Samoa, US
# 1             US  13.444300  144.793700                      Guam, US
# 2             US  15.097900  145.673900  Northern Mariana Islands, US
# 3             US  18.180117  -66.754367     Adjuntas, Puerto Rico, US
# 4             US  18.360255  -67.175131       Aguada, Puerto Rico, US
#
#       Date  Confirmed  Deaths
# 0  1/22/20          0       0
# 1  1/22/20          0       0
# ...

# %%
data.describe
# Out:
# <bound method NDFrame.describe of              UID iso2 iso3  code3     FIPS          Admin2  \
# 0             16   AS  ASM     16     60.0             NaN
# 1            316   GU  GUM    316     66.0             NaN
# 2            580   MP  MNP    580     69.0             NaN
# 3       63072001   PR  PRI    630  72001.0        Adjuntas
# 4       63072003   PR  PRI    630  72003.0          Aguada
# ...          ...  ...  ...    ...      ...             ...
# 627915  84070016   US  USA    840      NaN    Central Utah
# 627916  84070017   US  USA    840      NaN  Southeast Utah
# 627917  84070018   US  USA    840      NaN  Southwest Utah
# 627918  84070019   US  USA    840      NaN       TriCounty
# 627919  84070020   US  USA    840      NaN    Weber-Morgan
#
#                   Province_State Country_Region        Lat       Long_  \
# 0                 American Samoa             US -14.271000 -170.132000
# 1                           Guam             US  13.444300  144.793700
# ...

# %%
data.columns
# Out:
# Index(['UID', 'iso2', 'iso3', 'code3', 'FIPS', 'Admin2', 'Province_State',
#        'Country_Region', 'Lat', 'Long_', 'Combined_Key', 'Date', 'Confirmed',
#        'Deaths'],
#       dtype='object')

# %%
data.tail()
# Out:
#              UID iso2 iso3  code3  FIPS          Admin2 Province_State  \
# 627915  84070016   US  USA    840   NaN    Central Utah           Utah
# 627916  84070017   US  USA    840   NaN  Southeast Utah           Utah
# 627917  84070018   US  USA    840   NaN  Southwest Utah           Utah
# 627918  84070019   US  USA    840   NaN       TriCounty           Utah
# 627919  84070020   US  USA    840   NaN    Weber-Morgan           Utah
#
#        Country_Region        Lat       Long_              Combined_Key  \
# 627915             US  39.372319 -111.575868    Central Utah, Utah, US
# 627916             US  38.996171 -110.701396  Southeast Utah, Utah, US
# 627917             US  37.854472 -111.441876  Southwest Utah, Utah, US
# 627918             US  40.124915 -109.517442       TriCounty, Utah, US
# 627919             US  41.271160 -111.914512    Weber-Morgan, Utah, US
#
#            Date  Confirmed  Deaths
# 627915  7/27/20        347       1
# 627916  7/27/20         70       0
# ...

# %%
data.isnull().sum()
# Out:
# UID                  0
# iso2                 0
# iso3                 0
# code3                0
# FIPS              1880
# Admin2            1128
# Province_State       0
# Country_Region       0
# Lat                  0
# Long_                0
# Combined_Key         0
# Date                 0
# Confirmed            0
# Deaths               0
# dtype: int64

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/content/drive/MyDrive/full_grouped.csv")
data.head()
# Out:
#          Date Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0  2020-01-22    Afghanistan          0       0          0       0          0
# 1  2020-01-22        Albania          0       0          0       0          0
# 2  2020-01-22        Algeria          0       0          0       0          0
# 3  2020-01-22        Andorra          0       0          0       0          0
# 4  2020-01-22         Angola          0       0          0       0          0
#
#    New deaths  New recovered             WHO Region
# 0           0              0  Eastern Mediterranean
# 1           0              0                 Europe
# 2           0              0                 Africa
# 3           0              0                 Europe
# 4           0              0                 Africa

# %%
data.describe
# Out:
# <bound method NDFrame.describe of              Date      Country/Region  Confirmed  Deaths  Recovered  Active  \
# 0      2020-01-22         Afghanistan          0       0          0       0
# 1      2020-01-22             Albania          0       0          0       0
# 2      2020-01-22             Algeria          0       0          0       0
# 3      2020-01-22             Andorra          0       0          0       0
# 4      2020-01-22              Angola          0       0          0       0
# ...           ...                 ...        ...     ...        ...     ...
# 35151  2020-07-27  West Bank and Gaza      10621      78       3752    6791
# 35152  2020-07-27      Western Sahara         10       1          8       1
# 35153  2020-07-27               Yemen       1691     483        833     375
# 35154  2020-07-27              Zambia       4552     140       2815    1597
# 35155  2020-07-27            Zimbabwe       2704      36        542    2126
#
# ...
